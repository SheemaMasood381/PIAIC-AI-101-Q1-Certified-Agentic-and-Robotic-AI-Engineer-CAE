# %% [markdown]
# # Project 01 (a): Basic Madlibs
#
# This is a simple Python project designed for beginners to practice string concatenation and user input.
# The program generates a fun and interactive story by asking the user for different types of words
# (such as adjectives

# %%
def basic_madlib():
    adj = input("Adjective: ")
    verb1 = input("Verb: ")
    verb2 = input("Verb: ")
    famous_person = input("Famous person: ")

    madlib = f"Computer programming is so {adj}! It makes me so excited all the time because \
    I love to {verb1}. Stay hydrated and {verb2} like you are {famous_person}!"

    print(madlib)

if __name__ == "__main__":
    print("Running Project 01 (a): Basic Madlibs")
    basic_madlib()
# Out:
# Running Project 01 (a): Basic Madlibs
# Adjective: good
# Verb: walk
# Verb: drink
# Famous person: imran khan
# Computer programming is so good ! It makes me so excited all the time because     I love to walk. Stay hydrated and drink like you are imran khan!

# %% [markdown]
# ## Project 01 (b): Madlibs Randomizer
# Randomly selects a Madlib template from a set of predefined templates and generates a Madlib story. The templates are defined in separate functions within this script, and the script uses the `random.choice` function to select one at random.

# %%
import random

def code_madlib():
    adj = input("Adjective: ")
    verb1 = input("Verb: ")
    verb2 = input("Verb: ")
    famous_person = input("Famous person: ")

    madlib = f"Computer programming is so {adj}! It makes me so excited all the time because \
    I love to {verb1}. Stay hydrated and {verb2} like you are {famous_person}!"

    print(madlib)

def hp_madlib():
    adj = input("Adjective: ")
    noun = input("Noun: ")
    verb = input("Verb: ")
    place = input("Place: ")

    madlib = f"It was a {adj} day at Hogwarts. Harry and his friends were {verb} in the {place} when they found a mysterious {noun}."

    print(madlib)

def hunger_games_madlib():
    adj = input("Adjective: ")
    noun = input("Noun: ")
    past_verb = input("Past tense verb: ")
    place = input("Place: ")

    madlib = f"In the {adj} world of Panem, a young tribute found a {noun} that changed everything. They {past_verb} through the {place} to survive."

    print(madlib)

def zombie_madlib():
    adj = input("Adjective: ")
    noun = input("Noun: ")
    verb = input("Verb: ")
    place = input("Place: ")

    madlib = f"During the {adj} zombie apocalypse, survivors needed to {verb} quickly. They found a safe house in the {place} with enough {noun} to last for weeks."

    print(madlib)

def random_madlib():
    madlibs = [code_madlib, hp_madlib, hunger_games_madlib, zombie_madlib]
    m = random.choice(madlibs)
    m()

if __name__ == "__main__":
    print("Running Project 01 (b): Madlibs Randomizer")
    random_madlib()
# Out:
# Running Project 01 (b): Madlibs Randomizer
# Adjective: cool
# Noun: food
# Verb: eat
# Place: karachi
# During the cool zombie apocalypse, survivors needed to eat quickly. They found a safe house in the karachi with enough food to last for weeks.

# %% [markdown]
# # Combining Both Projects in a Single Script
# ## lets combine both projects into a single script for easy testing and submission<

# %%
import random

def basic_madlib():
    adj = input("Adjective: ")
    verb1 = input("Verb: ")
    verb2 = input("Verb: ")
    famous_person = input("Famous person: ")

    madlib = f"Computer programming is so {adj}! It makes me so excited all the time because \
    I love to {verb1}. Stay hydrated and {verb2} like you are {famous_person}!"

    print(madlib)

def code_madlib():
    adj = input("Adjective: ")
    verb1 = input("Verb: ")
    verb2 = input("Verb: ")
    famous_person = input("Famous person: ")

    madlib = f"Computer programming is so {adj}! It makes me so excited all the time because \
    I love to {verb1}. Stay hydrated and {verb2} like you are {famous_person}!"

    print(madlib)

def hp_madlib():
    adj = input("Adjective: ")
    noun = input("Noun: ")
    verb = input("Verb: ")
    place = input("Place: ")

    madlib = f"It was a {adj} day at Hogwarts. Harry and his friends were {verb} in the {place} when they found a mysterious {noun}."

    print(madlib)

def hunger_games_madlib():
    adj = input("Adjective: ")
    noun = input("Noun: ")
    past_verb = input("Past tense verb: ")
    place = input("Place: ")

    madlib = f"In the {adj} world of Panem, a young tribute found a {noun} that changed everything. They {past_verb} through the {place} to survive."

    print(madlib)

def zombie_madlib():
    adj = input("Adjective: ")
    noun = input("Noun: ")
    verb = input("Verb: ")
    place = input("Place: ")

    madlib = f"During the {adj} zombie apocalypse, survivors needed to {verb} quickly. They found a safe house in the {place} with enough {noun} to last for weeks."

    print(madlib)

def random_madlib():
    madlibs = [code_madlib, hp_madlib, hunger_games_madlib, zombie_madlib]
    m = random.choice(madlibs)
    m()

if __name__ == "__main__":
    print("Select a project to run:")
    print("1. Basic Madlibs")
    print("2. Madlibs Randomizer")

    choice = input("Enter the number of the project you want to run: ")

    if choice == "a":
        print("Running Project 01 (a): Basic Madlibs")
        basic_madlib()
    elif choice == "b":
        print("Running Project 01 (b): Madlibs Randomizer")
        random_madlib()
    else:
        print("Invalid choice. Please run the script again and select either a or b.")
# Out:
# Select a project to run:
# 1. Basic Madlibs
# 2. Madlibs Randomizer
# Enter the number of the project you want to run: b
# Running Project 01 (b): Madlibs Randomizer
# Adjective: clear
# Noun: water
# Verb: eat
# Place: karachi
# During the clear zombie apocalypse, survivors needed to eat quickly. They found a safe house in the karachi with enough water to last for weeks.

# %% [markdown]
# -------------
